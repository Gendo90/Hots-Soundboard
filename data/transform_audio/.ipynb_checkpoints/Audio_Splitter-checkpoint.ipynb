# %%
# Import the AudioSegment class for processing audio and the 
# split_on_silence function for separating out silent chunks.
from pydub import AudioSegment
from pydub.silence import split_on_silence

import speech_recognition as sr
# obtain path to "english.wav" in the same folder as this script
from os import path

# AudioSegment.ffmpeg = "C:/Users/patri/anaconda3/ffmpeg/bin/ffmpeg.exe"
# AudioSegment.converter = "C:/Users/patri/anaconda3/ffmpeg/bin/ffmpeg.exe"
# AudioSegment.ffprobe = "C:/Users/patri/anaconda3/ffmpeg/bin/ffprobe.exe"

# %%
# Define a function to normalize a chunk to a target amplitude.
def match_target_amplitude(aChunk, target_dBFS):
    ''' Normalize given audio chunk '''
    change_in_dBFS = target_dBFS - aChunk.dBFS
    return aChunk.apply_gain(change_in_dBFS)


def split_apart_recording(audio):
    print("starting function")
    # Split track where the silence is 2 seconds or more and get chunks using 
    # the imported function.
    chunks = split_on_silence (
        # Use the loaded audio.
        audio, 
        # Specify that a silent chunk must be at least 2 seconds or 2000 ms long.
        min_silence_len = 1200,
        # Consider a chunk silent if it's quieter than -16 dBFS.
        # (You may want to adjust this parameter.)
        silence_thresh = -44
    )
    print("split on silence already")
    print(len(chunks))

    # Process each chunk with your parameters
    for i, chunk in enumerate(chunks):
        print("on chunk {}".format(i+1))
        # Create a silence chunk that's 0.5 seconds (or 500 ms) long for padding.
        silence_chunk = AudioSegment.silent(duration=500)

        # Add the padding chunk to beginning and end of the entire chunk.
        audio_chunk = silence_chunk + chunk + silence_chunk
#         audio_chunk=chunk

        # Normalize the entire chunk. 
        #NOTE: Add back later if necessary
        normalized_chunk = match_target_amplitude(audio_chunk, -20.0)

        # Export the audio chunk with new bitrate.
        print("Exporting chunk{0}.mp3.".format(i+1))
        #could also use normalized chunk if necessary and that feature is used
        normalized_chunk.export(
            "../output/chunk{0}.wav".format(i+1),
            bitrate = "192k",
            format = "wav"
        )
        print("Exported chunk {}".format(i+1))

# %%
# Load your audio.
audio = AudioSegment.from_mp3("Tyrael-FULL-Quotes-Heroes-of-the-Storm.mp3")
print(audio)
# Out:
# <pydub.audio_segment.AudioSegment object at 0x0000019F5435D9C8>

# %%
split_apart_recording(audio)
# Out:
# starting function
# split on silence already
# 159
# on chunk 1
# Exporting chunk1.mp3.
# Exported chunk 1
# on chunk 2
# Exporting chunk2.mp3.
# Exported chunk 2
# on chunk 3
# Exporting chunk3.mp3.
# Exported chunk 3
# on chunk 4
# Exporting chunk4.mp3.
# Exported chunk 4
# on chunk 5
# Exporting chunk5.mp3.
# Exported chunk 5
# on chunk 6
# Exporting chunk6.mp3.
# Exported chunk 6
# on chunk 7
# Exporting chunk7.mp3.
# Exported chunk 7
# on chunk 8
# Exporting chunk8.mp3.
# Exported chunk 8
# on chunk 9
# Exporting chunk9.mp3.
# Exported chunk 9
# on chunk 10
# Exporting chunk10.mp3.
# Exported chunk 10
# on chunk 11
# Exporting chunk11.mp3.
# Exported chunk 11
# on chunk 12
# Exporting chunk12.mp3.
# Exported chunk 12
# on chunk 13
# Exporting chunk13.mp3.
# Exported chunk 13
# on chunk 14
# Exporting chunk14.mp3.
# Exported chunk 14
# on chunk 15
# Exporting chunk15.mp3.
# Exported chunk 15
# on chunk 16
# Exporting chunk16.mp3.
# Exported chunk 16
# on chunk 17
# Exporting chunk17.mp3.
# Exported chunk 17
# on chunk 18
# Exporting chunk18.mp3.
# Exported chunk 18
# on chunk 19
# Exporting chunk19.mp3.
# Exported chunk 19
# on chunk 20
# Exporting chunk20.mp3.
# Exported chunk 20
# on chunk 21
# Exporting chunk21.mp3.
# Exported chunk 21
# on chunk 22
# Exporting chunk22.mp3.
# Exported chunk 22
# on chunk 23
# Exporting chunk23.mp3.
# Exported chunk 23
# on chunk 24
# Exporting chunk24.mp3.
# Exported chunk 24
# on chunk 25
# Exporting chunk25.mp3.
# Exported chunk 25
# on chunk 26
# Exporting chunk26.mp3.
# Exported chunk 26
# on chunk 27
# Exporting chunk27.mp3.
# Exported chunk 27
# on chunk 28
# Exporting chunk28.mp3.
# Exported chunk 28
# on chunk 29
# Exporting chunk29.mp3.
# Exported chunk 29
# on chunk 30
# Exporting chunk30.mp3.
# Exported chunk 30
# on chunk 31
# Exporting chunk31.mp3.
# Exported chunk 31
# on chunk 32
# Exporting chunk32.mp3.
# Exported chunk 32
# on chunk 33
# Exporting chunk33.mp3.
# Exported chunk 33
# on chunk 34
# Exporting chunk34.mp3.
# Exported chunk 34
# on chunk 35
# Exporting chunk35.mp3.
# Exported chunk 35
# on chunk 36
# Exporting chunk36.mp3.
# Exported chunk 36
# on chunk 37
# Exporting chunk37.mp3.
# Exported chunk 37
# on chunk 38
# Exporting chunk38.mp3.
# Exported chunk 38
# on chunk 39
# Exporting chunk39.mp3.
# Exported chunk 39
# on chunk 40
# Exporting chunk40.mp3.
# Exported chunk 40
# on chunk 41
# Exporting chunk41.mp3.
# Exported chunk 41
# on chunk 42
# Exporting chunk42.mp3.
# Exported chunk 42
# on chunk 43
# Exporting chunk43.mp3.
# Exported chunk 43
# on chunk 44
# Exporting chunk44.mp3.
# Exported chunk 44
# on chunk 45
# Exporting chunk45.mp3.
# Exported chunk 45
# on chunk 46
# Exporting chunk46.mp3.
# Exported chunk 46
# on chunk 47
# Exporting chunk47.mp3.
# Exported chunk 47
# on chunk 48
# Exporting chunk48.mp3.
# Exported chunk 48
# on chunk 49
# Exporting chunk49.mp3.
# Exported chunk 49
# on chunk 50
# Exporting chunk50.mp3.
# Exported chunk 50
# on chunk 51
# Exporting chunk51.mp3.
# Exported chunk 51
# on chunk 52
# Exporting chunk52.mp3.
# Exported chunk 52
# on chunk 53
# Exporting chunk53.mp3.
# Exported chunk 53
# on chunk 54
# Exporting chunk54.mp3.
# Exported chunk 54
# on chunk 55
# Exporting chunk55.mp3.
# Exported chunk 55
# on chunk 56
# Exporting chunk56.mp3.
# Exported chunk 56
# on chunk 57
# Exporting chunk57.mp3.
# Exported chunk 57
# on chunk 58
# Exporting chunk58.mp3.
# Exported chunk 58
# on chunk 59
# Exporting chunk59.mp3.
# Exported chunk 59
# on chunk 60
# Exporting chunk60.mp3.
# Exported chunk 60
# on chunk 61
# Exporting chunk61.mp3.
# Exported chunk 61
# on chunk 62
# Exporting chunk62.mp3.
# Exported chunk 62
# on chunk 63
# Exporting chunk63.mp3.
# Exported chunk 63
# on chunk 64
# Exporting chunk64.mp3.
# Exported chunk 64
# on chunk 65
# Exporting chunk65.mp3.
# Exported chunk 65
# on chunk 66
# Exporting chunk66.mp3.
# Exported chunk 66
# on chunk 67
# Exporting chunk67.mp3.
# Exported chunk 67
# on chunk 68
# Exporting chunk68.mp3.
# Exported chunk 68
# on chunk 69
# Exporting chunk69.mp3.
# Exported chunk 69
# on chunk 70
# Exporting chunk70.mp3.
# Exported chunk 70
# on chunk 71
# Exporting chunk71.mp3.
# Exported chunk 71
# on chunk 72
# Exporting chunk72.mp3.
# Exported chunk 72
# on chunk 73
# Exporting chunk73.mp3.
# Exported chunk 73
# on chunk 74
# Exporting chunk74.mp3.
# Exported chunk 74
# on chunk 75
# Exporting chunk75.mp3.
# Exported chunk 75
# on chunk 76
# Exporting chunk76.mp3.
# Exported chunk 76
# on chunk 77
# Exporting chunk77.mp3.
# Exported chunk 77
# on chunk 78
# Exporting chunk78.mp3.
# Exported chunk 78
# on chunk 79
# Exporting chunk79.mp3.
# Exported chunk 79
# on chunk 80
# Exporting chunk80.mp3.
# Exported chunk 80
# on chunk 81
# Exporting chunk81.mp3.
# Exported chunk 81
# on chunk 82
# Exporting chunk82.mp3.
# Exported chunk 82
# on chunk 83
# Exporting chunk83.mp3.
# Exported chunk 83
# on chunk 84
# Exporting chunk84.mp3.
# Exported chunk 84
# on chunk 85
# Exporting chunk85.mp3.
# Exported chunk 85
# on chunk 86
# Exporting chunk86.mp3.
# Exported chunk 86
# on chunk 87
# Exporting chunk87.mp3.
# Exported chunk 87
# on chunk 88
# Exporting chunk88.mp3.
# Exported chunk 88
# on chunk 89
# Exporting chunk89.mp3.
# Exported chunk 89
# on chunk 90
# Exporting chunk90.mp3.
# Exported chunk 90
# on chunk 91
# Exporting chunk91.mp3.
# Exported chunk 91
# on chunk 92
# Exporting chunk92.mp3.
# Exported chunk 92
# on chunk 93
# Exporting chunk93.mp3.
# Exported chunk 93
# on chunk 94
# Exporting chunk94.mp3.
# Exported chunk 94
# on chunk 95
# Exporting chunk95.mp3.
# Exported chunk 95
# on chunk 96
# Exporting chunk96.mp3.
# Exported chunk 96
# on chunk 97
# Exporting chunk97.mp3.
# Exported chunk 97
# on chunk 98
# Exporting chunk98.mp3.
# Exported chunk 98
# on chunk 99
# Exporting chunk99.mp3.
# Exported chunk 99
# on chunk 100
# Exporting chunk100.mp3.
# Exported chunk 100
# on chunk 101
# Exporting chunk101.mp3.
# Exported chunk 101
# on chunk 102
# Exporting chunk102.mp3.
# Exported chunk 102
# on chunk 103
# Exporting chunk103.mp3.
# Exported chunk 103
# on chunk 104
# Exporting chunk104.mp3.
# Exported chunk 104
# on chunk 105
# Exporting chunk105.mp3.
# Exported chunk 105
# on chunk 106
# Exporting chunk106.mp3.
# Exported chunk 106
# on chunk 107
# Exporting chunk107.mp3.
# Exported chunk 107
# on chunk 108
# Exporting chunk108.mp3.
# Exported chunk 108
# on chunk 109
# Exporting chunk109.mp3.
# Exported chunk 109
# on chunk 110
# Exporting chunk110.mp3.
# Exported chunk 110
# on chunk 111
# Exporting chunk111.mp3.
# Exported chunk 111
# on chunk 112
# Exporting chunk112.mp3.
# Exported chunk 112
# on chunk 113
# Exporting chunk113.mp3.
# Exported chunk 113
# on chunk 114
# Exporting chunk114.mp3.
# Exported chunk 114
# on chunk 115
# Exporting chunk115.mp3.
# Exported chunk 115
# on chunk 116
# Exporting chunk116.mp3.
# Exported chunk 116
# on chunk 117
# Exporting chunk117.mp3.
# Exported chunk 117
# on chunk 118
# Exporting chunk118.mp3.
# Exported chunk 118
# on chunk 119
# Exporting chunk119.mp3.
# Exported chunk 119
# on chunk 120
# Exporting chunk120.mp3.
# Exported chunk 120
# on chunk 121
# Exporting chunk121.mp3.
# Exported chunk 121
# on chunk 122
# Exporting chunk122.mp3.
# Exported chunk 122
# on chunk 123
# Exporting chunk123.mp3.
# Exported chunk 123
# on chunk 124
# Exporting chunk124.mp3.
# Exported chunk 124
# on chunk 125
# Exporting chunk125.mp3.
# Exported chunk 125
# on chunk 126
# Exporting chunk126.mp3.
# Exported chunk 126
# on chunk 127
# Exporting chunk127.mp3.
# Exported chunk 127
# on chunk 128
# Exporting chunk128.mp3.
# Exported chunk 128
# on chunk 129
# Exporting chunk129.mp3.
# Exported chunk 129
# on chunk 130
# Exporting chunk130.mp3.
# Exported chunk 130
# on chunk 131
# Exporting chunk131.mp3.
# Exported chunk 131
# on chunk 132
# Exporting chunk132.mp3.
# Exported chunk 132
# on chunk 133
# Exporting chunk133.mp3.
# Exported chunk 133
# on chunk 134
# Exporting chunk134.mp3.
# Exported chunk 134
# on chunk 135
# Exporting chunk135.mp3.
# Exported chunk 135
# on chunk 136
# Exporting chunk136.mp3.
# Exported chunk 136
# on chunk 137
# Exporting chunk137.mp3.
# Exported chunk 137
# on chunk 138
# Exporting chunk138.mp3.
# Exported chunk 138
# on chunk 139
# Exporting chunk139.mp3.
# Exported chunk 139
# on chunk 140
# Exporting chunk140.mp3.
# Exported chunk 140
# on chunk 141
# Exporting chunk141.mp3.
# Exported chunk 141
# on chunk 142
# Exporting chunk142.mp3.
# Exported chunk 142
# on chunk 143
# Exporting chunk143.mp3.
# Exported chunk 143
# on chunk 144
# Exporting chunk144.mp3.
# Exported chunk 144
# on chunk 145
# Exporting chunk145.mp3.
# Exported chunk 145
# on chunk 146
# Exporting chunk146.mp3.
# Exported chunk 146
# on chunk 147
# Exporting chunk147.mp3.
# Exported chunk 147
# on chunk 148
# Exporting chunk148.mp3.
# Exported chunk 148
# on chunk 149
# Exporting chunk149.mp3.
# Exported chunk 149
# on chunk 150
# Exporting chunk150.mp3.
# Exported chunk 150
# on chunk 151
# Exporting chunk151.mp3.
# Exported chunk 151
# on chunk 152
# Exporting chunk152.mp3.
# Exported chunk 152
# on chunk 153
# Exporting chunk153.mp3.
# Exported chunk 153
# on chunk 154
# Exporting chunk154.mp3.
# Exported chunk 154
# on chunk 155
# Exporting chunk155.mp3.
# Exported chunk 155
# on chunk 156
# Exporting chunk156.mp3.
# Exported chunk 156
# on chunk 157
# Exporting chunk157.mp3.
# Exported chunk 157
# on chunk 158
# Exporting chunk158.mp3.
# Exported chunk 158
# on chunk 159
# Exporting chunk159.mp3.
# Exported chunk 159

# %%
def audio_transcription(num_chunks):
    # use the audio file as the audio source
    r = sr.Recognizer()
    
    for i in range(1, num_chunks+1):
        with sr.AudioFile("../output/chunk{}.wav".format(i)) as source:
            chunk = r.record(source)  # read the entire audio file

        # recognize speech using Sphinx
        try:
            print("Sphinx thinks you said -> " + r.recognize_sphinx(chunk))
        except sr.UnknownValueError:
            print("Sphinx could not understand audio")
        except sr.RequestError as e:
            print("Sphinx error; {0}".format(e))

# %%
audio_transcription(159)
# Out:
# Sphinx thinks you said -> and it's mortal
# Sphinx thinks you said -> what do you think
# Sphinx thinks you said -> i'm sorry did you say something i was busy thinking about justice
# Sphinx thinks you said -> you want more hope you never know what your curiosity likes of which
# Sphinx thinks you said -> saint louis just to sort of do love this war and you'll get lost to be doomed to imagine what to visit the bullshit these days and ha-ha ha ha ha ha ha ha ha and where are we do and where does it didn't work
# Sphinx thinks you said -> just because i'm mortal bosnia one to wait around forever
# Sphinx thinks you said -> the person's body glaring at you right now
# Sphinx thinks you said -> in heaven everything is fine
# Sphinx thinks you said -> you can always sell and angels have big when their wings locker
# Sphinx thinks you said -> perfect gemma activated
# Sphinx thinks you said -> you're quite proficient at likud do ya bills or you might be right up your alley
# Sphinx thinks you said -> ever taco bell rings basulto r. manifests as the physical representation of an angel's wings
# Sphinx thinks you said -> of course is that what i felt from heaven winds are you trying to draw me
# Sphinx thinks you said -> just to susan blind eye to face but i'm laing
# Sphinx thinks you said -> there is no wisdom in the high heavens and no safety wooden sanctuary po on to the president's state of concerns
# Sphinx thinks you said -> on news lines of the one bill out of humanity saving your people from being erased from creation i'm beginning to regret that decision
# Sphinx thinks you said -> blessings to you and mortal
# Sphinx thinks you said -> my eternal gratitude bureau
# Sphinx thinks you said -> so it is gone judy i'm not warn you
# Sphinx thinks you said -> my wrath has been stated retribution job in mind
# Sphinx thinks you said -> the plot and call it demands justice
# Sphinx thinks you said -> who taught you reverence george you want to
# Sphinx thinks you said -> justice dogs all these whew
# Sphinx thinks you said -> the pursuit of justice is about as big
# Sphinx thinks you said -> i have reforms
# Sphinx thinks you said -> it's not unusual to see you fly
# Sphinx thinks you said -> now these moves modern art
# Sphinx thinks you said -> i must leave you
# Sphinx thinks you said -> i'm telling you to get
# Sphinx thinks you said -> grandsons
